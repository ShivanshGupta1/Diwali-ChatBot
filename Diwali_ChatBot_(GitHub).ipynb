# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivanshGupta1/Diwali-ChatBot/blob/main/Diwali_ChatBot_(GitHub).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
budget = int(input("What is your budget? "))
print("Ok, so we can say your budget is",budget, "INR...")
items = set()
answer = 0;
enough = "";
def end(answer,budget,items):
   print("Your items are", items, "and the price remaining is",budget)
   print("Do you want to buy more?","You can restart with your remaining budget")
def decorations(answer,budget,items):
  if budget>150:
    answer1 = input("Would you like decorations in your budget? ")
    if answer1.lower()=="yes":
      newbudget1 = budget-150
      if newbudget1>0:
        items.add("decorations");
        budget-=150
        crackers(answer,budget,items);
      else:
        print("Your budget does not allow you to buy that!")
        crackers(answer,budget,items);
    else:
      crackers(answer,budget,items);
  else:
    end(answer,budget,items);
   
def crackers(answer,budget,items):
  if budget>150:
    answer2 = input("Would you like crackers in your budget? ")
    if answer2.lower()=="yes":
      newbudget2 = budget-300
      if newbudget2>0:
        items.add("crackers");
        budget-=300
        barfi(answer,budget,items);
      else:
        print("Your budget does not allow you to buy that!")
        barfi(answer,budget,items);
    else:
      barfi(answer,budget,items);
  else:
    end(answer,budget,items);
def barfi(answer,budget,items):
  if budget>150:
    answer3 = input("Would you like barfi in your budget? ")
    if answer3.lower()=="yes":
      newbudget3 = budget-500
      if newbudget3>0:
        items.add("barfi");
        budget-=500
        laddos(answer,budget,items);
      else:
        print("Your budget does not allow you to buy that!")
        laddos(answer,budget,items);
    else:
      laddos(answer,budget,items);
  else:
    end(answer,budget,items);
def laddos(answer,budget,items):
  if budget>150:
    answer4 = input("Would you like laddos in your budget? ")
    if answer4.lower()=="yes":
      newbudget4 = budget-600
      if newbudget4>0:
        items.add("laddos");
        budget-=600
        lights(answer,budget,items);
      else:
        print("Your budget does not allow you to buy that!")
        lights(answer,budget,items);
    else:
      lights(answer,budget,items);
  else:
    end(answer,budget,items);
def lights(answer,budget,items):
  if budget>150:
    answer5 = input("Would you like lights in your budget? ")
    if answer5.lower()=="yes":
      newbudget5 = budget-800
      if newbudget5>0:
        items.add("lights");
        budget-=800
        food(answer,budget,items);
      else:
        print("Your budget does not allow you to buy that!")
        food(answer,budget,items);
    else:
      food(answer,budget,items);
  else:
    end(answer,budget,items);
def food(answer,budget,items):
  if budget>150:
    answer6 = input("Would you like food in your budget? ")
    if answer6.lower()=="yes":
      newbudget6 = budget-1500
      if newbudget6>0:
        items.add("food");
        budget-=1500
        end(answer,budget,items);
      else:
        print("Your budget does not allow you to buy that!")
        end(answer,budget,items);
    else:
      end(answer,budget,items);
  else:
    end(answer,budget,items);

decorations(answer,budget,items);
# Out:
# What is your budget? 2000
# Ok, so we can say your budget is 2000 INR...
# Would you like decorations in your budget? yes
# Would you like crackers in your budget? yes
# Would you like barfi in your budget? no
# Would you like laddos in your budget? no
# Would you like lights in your budget? yes
# Would you like food in your budget? no
# Your items are {'decorations', 'lights', 'crackers'} and the price remaining is 750
# Do you want to buy more? You can restart with your remaining budget
